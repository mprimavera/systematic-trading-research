# %%
# comment
# 10

# %%
1 + 1
# Out:
# 2

# %%
1 - 3
# Out:
# -2

# %%
x = 'hello'

print(x)
# Out:
# hello

# %%
first = 'michael'
number = 10

print("Hello my name is {} and my number is {}".format(first, number))
# Out:
# Hello my name is michael and my number is 10

# %%
first = 'michael'
last = 'prim'

print("Hello my name is {x} and my number is {y}".format(x=first, y=number))
# Out:
# Hello my name is michael and my number is 10

# %%
import math

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
i = 1
while i < 5:
    print(f"i is currently {i}")
    i += 1
# Out:
# i is currently 1
# i is currently 2
# i is currently 3
# i is currently 4

# %%
for item in range(2,11,2):
    print(item)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
x = [1,2,3,4,5]

out = []
for num in x:
    out.append(num**2)


out
# Out:
# [1, 4, 9, 16, 25]

# %%
# Previous for-loop written as List Comprehension

[num**2 for num in x]
# Out:
# [1, 4, 9, 16, 25]

# %%
# Functions
# Lambda Expressions
# map and filter
# various useful methods

# %%
def my_func(param='default'):
    """
    This is the docstring
    """
    print(param)


my_func()
# Out:
# default
